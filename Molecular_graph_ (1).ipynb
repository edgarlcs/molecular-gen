# %% [markdown]
# First we have to initialize conda environments to work with google colab

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda init
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# no change     /root/.bashrc
# No action taken.

# %% [markdown]
# #MoFlow

# %%
# !conda create --name moflow python pandas matplotlib
# !conda activate moflow
# !conda install pytorch torchvision cudatoolkit=10.2 -c pytorch 
# !conda install rdkit  
# !conda install orderedset  
# !conda install tabulate  
# !conda install networkx  
# !conda install scipy 
# !conda install seaborn  
# !pip install cairosvg 
# !pip install tqdm
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/moflow
#
#   added / updated specs:
#     - matplotlib
#     - pandas
#     - python
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.3.2-h166bdaf_0
#   brotli             conda-forge/linux-64::brotli-1.0.9-h166bdaf_7
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h166bdaf_7
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   ca-certificates    conda-forge/linux-64::ca-certificates-2021.10.8-ha878542_0
#   certifi            conda-forge/linux-64::certifi-2021.10.8-py310hff52083_2
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-h5008d03_3
# ...

# %%
# !git clone https://github.com/calvin-zcx/moflow.git moflow
# Out:
# Cloning into 'moflow'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 105 (delta 32), reused 82 (delta 16), pack-reused 0
# Receiving objects: 100% (105/105), 32.86 MiB | 16.93 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !pip install rdkit-pypi

# %%
# !conda install rdkit
# !conda install ipykernel
# Out:
# done
# done
#
# # All requested packages already installed.
#
# done
# done
#
# # All requested packages already installed.

# %%
# %cd /content/moflow/data
# Out:
# /content/moflow/data

# %%
# !python data_preprocess.py --data_name qm9
# Out:
# args {'data_name': 'qm9', 'data_type': 'relgcn'}
# Preprocessing qm9 data:
# 100% 133885/133885 [01:10<00:00, 1894.56it/s]
# Save ./qm9_relgcn_kekulized_ggnp.npz done.
# Total time: 00:01:11

# %%
# %cd ../mflow
# Out:
# /content/moflow/mflow

# %%
# !python train_model.py --data_name qm9  --batch_size 256  --max_epochs 200 --gpu 0  --debug True  --save_dir=results/qm9_64gnn_128-64lin_1-1mask_0d6noise_convlu1  --b_n_flow 10  --b_hidden_ch 128,128  --a_n_flow 27 --a_hidden_gnn 64  --a_hidden_lin 128,64  --mask_row_size_list 1 --mask_row_stride_list 1 --noise_scale 0.6 --b_conv_lu 1  2>&1 | tee qm9_64gnn_128-64lin_1-1mask_0d6noise_convlu1.log
# Out:
# Streaming output truncated to the last 5000 lines.
# [3] CC1OC=CCC=C1F
# [4] CCC=NC=NCC=O
# [5] NC1(C2=CC2F)OC1O
# [6] CCOC=COCOO
# [7] CC1=CN=C2CC1=NO2
# [8] CCNC(=O)N=NC=O
# [9] O=C1CC=CCOC1O
# [10] O=CC=NC1C=CCO1
# [11] CC1C2OC12NCC=O
# [12] N=C1OC2=CC=CC1O2
# [13] CCCN=NN=CC=O
# [14] COCN=CC=NC#N
# [15] O=C1COCNC12NO2
# [16] CC1=CN1C1=NC(=O)O1
# [17] COC=NC=CN=NO
# [18] N=C1OC=NC(O)(F)O1
# [19] CC1CC(=O)C(=CO)O1
# [20] C#CCCC1CC=NN1
# [21] CCN=CNNC1=CO1
# [22] CC1(O)NOCC1C=O
# [23] N#CC1=[N+]=CCOC1F
# [24] O=CCN=C(F)N=CF
# [25] CCCOC1=COCO1
# [26] CC1C=C=N[O+]2CC12C
# [27] N=CN=[N+]=C1N=C2NC21
# [28] CC1OC(=NC(=N)O)O1
# [29] CC1N=CCN=CCN1
# [30] NC1=C(O)C2(O)COC12
# [31] CC1(O)C(CF)=NN1O
# [32] O=CC1=CC2ON=C1O2
# [33] CC1OCCN=C1CF
# [34] CCOc1onnc1C
# [35] CCC(=O)c1c[o+]on1
# [36] Cc1ncoc1CC=O
# [37] OCC=CC=NC=NO
# [38] O=CC=CCCOOO
# [39] C#CC1=NC12NN=NO2
# [40] CCNC(F)=NC=CF
# [41] O=CCN=C1OCCO1
# [42] O=Cc1ncc(=O)on1
# [43] CN=CCC(=O)C(N)F
# [44] CC1=CC(F)N=CN=C1
# ...

# %%
# !python generate.py --model_dir results/qm9_64gnn_128-64lin_1-1mask_0d6noise_convlu1 -snapshot model_snapshot_epoch_200 --gpu 0 --data_name qm9 --hyperparams-path moflow-params.json --batch-size 10000 --temperature 0.85 --delta 0.05 --n_experiments 5 --save_fig false --correct_validity true 2>&1 | tee qm9_random_generation.log
# Out:
# Streaming output truncated to the last 5000 lines.
# [5010] NC1=CC2C=C3CC2N13
# [5011] NC1=CN=COC1(O)F
# [5012] O=CC=C1C2C=CN1O2
# [5013] O=NCC1=CN=CCO1
# [5014] CCC1OC=NC1CO
# [5015] CN=NCC=NC=CN
# [5016] O=COc1[nH]cnc1O
# [5017] COC=CCCOC=O
# [5018] CC1NN=C2N=C1C2=O
# [5019] NCOCC1=CC=NC1
# [5020] O=CCC1=CN=NOC1
# [5021] OC1NC2(O)COC1O2
# [5022] O=C[O+](O)N1C2CCC21
# [5023] N=C1OC=CC(=O)C1O
# [5024] NC(=O)C=CC(N)=NO
# [5025] CN=CC(=O)C1C=C1N
# [5026] CC=CC(O)C1(F)CN1
# [5027] CCC1N=NC(C)CO1
# [5028] CN1N=NC=NC(O)=N1
# [5029] OC1CC2C=C1C(O)O2
# [5030] N=C1N=NC(F)=C1CO
# [5031] NC(=O)C1OC1C(F)F
# [5032] N#CC(=N)C1=NOCN1
# [5033] COC1=C=C2OCC12O
# [5034] CC=NN=CNC1=NO1
# [5035] O=CC12CCC(=O)C1O2
# [5036] N=C1CC=NC=NN=N1
# [5037] O=C1NC12CN=NC2F
# [5038] N=C(C=NO)C=NC=O
# [5039] N=C1C=NN=C(N)NC1
# [5040] O=CC=COC=CCO
# [5041] CN1N=Nc2cnc1o2
# [5042] NCC1C=CC(C=O)O1
# [5043] Oc1cnno1
# [5044] NC1C=NOC1C1CO1
# [5045] CC1CON=CN=C1F
# [5046] CNCC12CC1(O)ON2
# [5047] O=CC1OC1(O)CCF
# ...

# %% [markdown]
# #GF-VAE

# %%
# %cd /content

# %%
# !git clone https://github.com/chshm/GF-VAE.git gfvae
# Out:
# Cloning into 'gfvae'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 65 (delta 8), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (65/65), done.

# %%
# !cp -av '/content/moflow/data' '/content/gfvae/'
# !cp -av '/content/moflow/data' '/content/gfvae/mflow'
# Out:
# '/content/moflow/data/__init__.py' -> '/content/gfvae/data/__init__.py'
# '/content/moflow/data/data_frame_parser.py' -> '/content/gfvae/data/data_frame_parser.py'
# '/content/moflow/data/data_loader.py' -> '/content/gfvae/data/data_loader.py'
# '/content/moflow/data/data_preprocess.py' -> '/content/gfvae/data/data_preprocess.py'
# '/content/moflow/data/qm9.csv' -> '/content/gfvae/data/qm9.csv'
# '/content/moflow/data/qm9_property.csv' -> '/content/gfvae/data/qm9_property.csv'
# '/content/moflow/data/smile_to_graph.py' -> '/content/gfvae/data/smile_to_graph.py'
# '/content/moflow/data/transform_qm9.py' -> '/content/gfvae/data/transform_qm9.py'
# '/content/moflow/data/transform_zinc250k.py' -> '/content/gfvae/data/transform_zinc250k.py'
# '/content/moflow/data/valid_idx_qm9.json' -> '/content/gfvae/data/valid_idx_qm9.json'
# '/content/moflow/data/valid_idx_zinc.json' -> '/content/gfvae/data/valid_idx_zinc.json'
# ...

# %%
# !cp -av '/content/gfvae/mflow/data' '/content/gfvae/'
# Out:
# '/content/gfvae/mflow/data/__init__.py' -> '/content/gfvae/data/__init__.py'
# '/content/gfvae/mflow/data/data_frame_parser.py' -> '/content/gfvae/data/data_frame_parser.py'
# '/content/gfvae/mflow/data/data_loader.py' -> '/content/gfvae/data/data_loader.py'
# '/content/gfvae/mflow/data/data_preprocess.py' -> '/content/gfvae/data/data_preprocess.py'
# '/content/gfvae/mflow/data/qm9.csv' -> '/content/gfvae/data/qm9.csv'
# '/content/gfvae/mflow/data/qm9_property.csv' -> '/content/gfvae/data/qm9_property.csv'
# '/content/gfvae/mflow/data/smile_to_graph.py' -> '/content/gfvae/data/smile_to_graph.py'
# '/content/gfvae/mflow/data/transform_qm9.py' -> '/content/gfvae/data/transform_qm9.py'
# '/content/gfvae/mflow/data/transform_zinc250k.py' -> '/content/gfvae/data/transform_zinc250k.py'
# '/content/gfvae/mflow/data/valid_idx_qm9.json' -> '/content/gfvae/data/valid_idx_qm9.json'
# '/content/gfvae/mflow/data/valid_idx_zinc.json' -> '/content/gfvae/data/valid_idx_zinc.json'
# ...

# %%
# %cd /content/gfvae/mflow/data
# !python data_preprocess.py --data_name zinc250k
# Out:
# /content/gfvae/mflow/data
# args {'data_name': 'zinc250k', 'data_type': 'relgcn'}
# Preprocessing zinc250k data
# 100% 249455/249455 [03:22<00:00, 1232.97it/s]
# tcmalloc: large alloc 5763416064 bytes == 0x56285fcd2000 @  0x7f1e29b9b1e7 0x7f1e281bfa9e 0x7f1e281bfb34 0x7f1e282036e1 0x7f1e28206284 0x7f1e282066b7 0x7f1e28299e4b 0x5626e46191b9 0x5626e461a1e8 0x5626e468d4da 0x5626e45d0ea2 0x5626e4617370 0x5626e461a0d8 0x5626e4690cba 0x5626e45d0ea2 0x5626e4617370 0x5626e461a0d8 0x5626e468d4da 0x5626e45d0ea2 0x5626e45d20b9 0x5626e46b115b 0x5626e471cd53 0x5626e4727307 0x5626e47274dc 0x5626e4727a39 0x5626e4727b8c 0x7f1e28bccc87 0x5626e469d51d
# Save ./zinc250k_relgcn_kekulized_ggnp.npz done.
# Total time: 00:03:52

# %%
# %cd /content/gfvae/mflow
# Out:
# /content/gfvae/mflow

# %%
# !python train_model.py  --data_name zinc250k  --batch_size  128  --max_epochs 100 --gpu 0  --debug True  --save_dir=results/zinc250k_test001_2squeeze   --b_n_flow 5  --b_hidden_ch 128,128  --a_n_flow 15  --a_hidden_gnn 256  --a_hidden_lin  512,64   --mask_row_size_list 1 --mask_row_stride_list 1 --b_conv_lu 2
# Out:
# Streaming output truncated to the last 5000 lines.
# [23:59:30] Explicit valence for atom # 4 Br, 2, is greater than permitted
# [23:59:30] Explicit valence for atom # 15 O, 3, is greater than permitted
# [23:59:30] Explicit valence for atom # 17 F, 3, is greater than permitted
# [23:59:30] Explicit valence for atom # 17 F, 2, is greater than permitted
# [23:59:30] Explicit valence for atom # 19 Cl, 3, is greater than permitted
# [23:59:30] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# [23:59:30] Explicit valence for atom # 20 Br, 2, is greater than permitted
# [23:59:30] Explicit valence for atom # 20 F, 3, is greater than permitted
# [23:59:30] Explicit valence for atom # 20 F, 3, is greater than permitted
# [23:59:30] Explicit valence for atom # 20 F, 2, is greater than permitted
# [23:59:30] Explicit valence for atom # 17 O, 3, is greater than permitted
# [23:59:30] Explicit valence for atom # 17 O, 3, is greater than permitted
# ...

# %%
# %cd /content/gfvae/mflow
# Out:
# /content/gfvae/mflow

# %%
# !python generate.py --model_dir results/zinc250k_datatest_5_15 -snapshot model_snapshot_epoch_100 --gpu 0 --data_name zinc250k --hyperparams-path moflow-params.json --batch-size 1000 --temperature 0.85 --delta 0.05 --n_experiments 3 --save_fig True --correct_validity true
# Out:
# Start at Time: Fri May  6 23:59:35 2022
# loading hyperparamaters from results/zinc250k_datatest_5_15/moflow-params.json
# Traceback (most recent call last):
#   File "generate.py", line 449, in <module>
#     model_params = Hyperparameters(path=hyperparams_path)
#   File "../mflow/models/hyperparams.py", line 77, in __init__
#     raise Exception("{} does not exist".format(path))
# Exception: results/zinc250k_datatest_5_15/moflow-params.json does not exist

# %% [markdown]
# #MolGAN

# %%
# !conda install sklearn
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - sklearn
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/yongqyu/MolGAN-pytorch.git molgan
# Out:
# Cloning into 'molgan'...
# remote: Enumerating objects: 44, done.
# remote: Total 44 (delta 0), reused 0 (delta 0), pack-reused 44
# Unpacking objects: 100% (44/44), done.

# %%
# %cd /content/molgan/data
# Out:
# /content/molgan/data

# %%
# !bash download_dataset.sh
# Out:
# --2022-05-07 00:46:28--  http://deepchem.io.s3-website-us-west-1.amazonaws.com/datasets/gdb9.tar.gz
# Resolving deepchem.io.s3-website-us-west-1.amazonaws.com (deepchem.io.s3-website-us-west-1.amazonaws.com)... 52.219.120.3
# Connecting to deepchem.io.s3-website-us-west-1.amazonaws.com (deepchem.io.s3-website-us-west-1.amazonaws.com)|52.219.120.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44852087 (43M) [application/x-gzip]
# Saving to: ‘gdb9.tar.gz’
#
# gdb9.tar.gz         100%[===================>]  42.77M  66.2MB/s    in 0.6s
#
# 2022-05-07 00:46:29 (66.2 MB/s) - ‘gdb9.tar.gz’ saved [44852087/44852087]
#
# gdb9.sdf.csv
# gdb9.sdf
# --2022-05-07 00:46:31--  https://github.com/gablg1/ORGAN/raw/master/organ/NP_score.pkl.gz
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python sparse_molecular_dataset.py
# Out:
# 2022-05-07 00:46:36 Extracting gdb9.sdf..
# [00:46:36] Warning: molecule is tagged as 3D, but all Z coords are zero
# [00:46:36] Explicit valence for atom # 1 C, 5, is greater than permitted
# [00:46:36] ERROR: Could not sanitize molecule ending on line 9097
# [00:46:36] ERROR: Explicit valence for atom # 1 C, 5, is greater than permitted
# [00:46:36] Warning: molecule is tagged as 3D, but all Z coords are zero
# [00:46:36] Explicit valence for atom # 1 C, 5, is greater than permitted
# [00:46:36] ERROR: Could not sanitize molecule ending on line 35785
# [00:46:36] ERROR: Explicit valence for atom # 1 C, 5, is greater than permitted
# [00:46:36] Explicit valence for atom # 4 C, 5, is greater than permitted
# [00:46:36] ERROR: Could not sanitize molecule ending on line 62866
# [00:46:36] ERROR: Explicit valence for atom # 4 C, 5, is greater than permitted
# [00:46:36] Explicit valence for atom # 2 C, 5, is greater than permitted
# ...

# %%
# %cd /content/molgan
# Out:
# /content/molgan

# %%
# !pip install sklearn
# Out:
# ...
#      |████████████████████████████████| 24.8 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 306 kB 64.1 MB/s
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=ebec8550a4ca1ced5302a6810c9c6ae09f650688cf7d4621ac5c9a37385fa9bd
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
# !python main.py --batch_size 64 --num_iters 1000 --test_iters 1000
# Out:
# Streaming output truncated to the last 5000 lines.
# [03:01:32] non-ring atom 2 marked aromatic
# [03:01:32] non-ring atom 0 marked aromatic
# [03:01:32] non-ring atom 2 marked aromatic
# [03:01:32] Explicit valence for atom # 2 C, 5, is greater than permitted
# [03:01:32] non-ring atom 6 marked aromatic
# [03:01:32] non-ring atom 6 marked aromatic
# [03:01:32] non-ring atom 2 marked aromatic
# [03:01:32] non-ring atom 0 marked aromatic
# [03:01:32] non-ring atom 5 marked aromatic
# [03:01:32] non-ring atom 1 marked aromatic
# [03:01:32] non-ring atom 1 marked aromatic
# [03:01:32] non-ring atom 3 marked aromatic
# [03:01:32] non-ring atom 0 marked aromatic
# [03:01:32] non-ring atom 3 marked aromatic
# [03:01:32] non-ring atom 1 marked aromatic
# [03:01:32] non-ring atom 3 marked aromatic
# [03:01:32] non-ring atom 4 marked aromatic
# [03:01:32] non-ring atom 0 marked aromatic
# [03:01:32] non-ring atom 1 marked aromatic
# [03:01:32] non-ring atom 1 marked aromatic
# ...
